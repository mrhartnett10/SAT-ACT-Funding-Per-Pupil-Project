# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Decide on your problem statement that will guide your analysis for this project. For guidelines, sample prompts, or inspiration, check out the README.
#
# **To-Do:** *Replace this cell with your problem statement.*

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %% [markdown]
# **To-Do:** *Fill out this cell (or edit the above cell) with any other background or information that is necessary for your problem statement.*
#
# ### Problem Statement: What is the correlation between state spending per pupil and resulting SAT/ACT scores? Will higher spending correlate with higher scores on a state level?

# %% [markdown]
# ### Choose your Data
#
# There are 10 datasets included in the [`data`](./data/) folder for this project. You are required to pick **at least two** of these to complete your analysis. Feel free to use more than two if you would like, or add other relevant datasets you find online.
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`act_2019_ca.csv`](./data/act_2019_ca.csv): 2019 ACT Scores in California by School
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`sat_2019_by_intended_college_major.csv`](./data/sat_2019_by_intended_college_major.csv): 2019 SAT Scores by Intended College Major
# * [`sat_2019_ca.csv`](./data/sat_2019_ca.csv): 2019 SAT Scores in California by School
# * [`sat_act_by_college.csv`](./data/sat_act_by_college.csv): Ranges of Accepted ACT & SAT Student Scores by Colleges

# %% [markdown]
# **To-Do:** The data sets I have elected to use for my analysis are the act_2018.csv and the sat_2018.csv. As noted below, the most recently released financial data for state education funding that I was able to find is data from 2018. So to avoid comparing apples to oranges, we have to be consistent with our data reflected in the year choice. These two above sets will allow me to analyze the scores for both SAT and ACT on a state by state basis, but will also allow me to incorprate the different participation rates for each exam. As we will discover, some states trend heavily towards taking the SATs while some states have trended more towards the ACT. It will be important to keep this in mind as we go through our analysis and try to achieve an answer to our problem statement.

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Based on your problem statement and your chosen datasets, spend some time doing outside research on state policies or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. **Make sure that you cite your sources.**

# %% [markdown]
# Outside Research obtained from downloading excel sheet for education funding by state from: https://www.governing.com/finance/Education-Spending-Per-Student-By-State.html
#
# During research it was important to keep in mind that states have different populations so there funding will show accordingly (lower populations will require less funding, high pops will require higher funding). That is why I wanted to make sure I found a data set that would include the funding per pupil, which gives us a more comparable, equally scaled variable to work with.
#
# Per website above: Nationally, the 2018 data indicates $12,612 is spent on public education per student, up nearly $1,000 as compared to the 2016 data. Significant variation exists across states; New York spends more than $24,000 per student, while states like Utah and Idaho report spending less than a third as much.
#
# I wanted to include the above excerpt because with just this tidbit it leads me to believe that the observed increase in investing in students is motivated by the belief that there is a positive correlation between spending per pupil and "success" (higher scores). Let's unpack some of the data and see if we can draw any correlations.

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:
def mean_calculator(x):
    count = 0
    for i in x:
        count += i
    return count/len(x)

# %%
test = [1, 2, 4, 5, 10, 12,]
mean_calculator(test)
# Out:
# 5.666666666666667

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:
def std_calculator(x):
    average = mean_calculator(x)
    count = 0
    for i in x:
        count += (i-average)**2
    return (count/len(x))**.5

# %%
std_calculator(test)
# Out:
# 4.027681991198191

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
# Code:
def percent_to_float(x):
    new = x.rstrip('%')
    return float(new)/100

# %%
percent_to_float('30.5%')
# Out:
# 0.305

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
# Imports:
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary:
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values.
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
# 4. Fix any errors you identified in steps 2-3.
# 5. Display the data types of each feature.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %% [markdown]
# ### Loading Data

# %%
path = '/Users/michaelhartnett/Projects/GA/DSI/Class Projects/SAT:ACT/project_1/data'

# %%
# Code:
sat_2018 = pd.read_csv(f'{path}/sat_2018.csv', index_col=0)
act_2018 = pd.read_csv(f'{path}/act_2018.csv', index_col=0)
state_funding_2018 = pd.read_csv(f'{path}/state_funding_2018.csv', index_col=0)

# %% [markdown]
# ### 1. Displaying Our Data

# %% [markdown]
# Using .head() will allow us to minimize space, but get an idea of what to expect in our dataset (will display the first 5 rows of the dataframe.

# %%
#1. Display Data
sat_2018.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            6%                                 595   571   1166
# 1      Alaska           43%                                 562   544   1106
# 2     Arizona           29%                                 577   572   1149
# 3    Arkansas            5%                                 592   576   1169
# 4  California           60%                                 540   536   1076

# %%
#1. Display Data
act_2018.head()
# Out:
#         State Participation  Composite
# 0     Alabama          100%       19.1
# 1      Alaska           33%       20.8
# 2     Arizona           66%       19.2
# 3    Arkansas          100%       19.4
# 4  California           27%       22.7

# %%
#1. Display Data
state_funding_2018.head()
# Out:
#   Geographic Area  Total  Spending Per Pupil  Total Spending  \
# 0  -United States               12611.842660       720944995
# 1         Alabama                9696.181213         8068664
# 2          Alaska               17725.939250         2526833
# 3         Arizona                8238.534796         8861562
# 4        Arkansas               10138.680596         5562235
#
#    Instruction Spending Per Pupil  Total Instruction Spending  \
# 0                     7649.510417                   382484159
# 1                     5520.600270                     4102597
# 2                     9495.439220                     1261678
# 3                     4440.787784                     4126812
# 4                     5723.209691                     2750549
#
#    Support Spending Per Pupil  Total Support Spending
# 0                 4457.058229               216533516
# 1                 3526.601356                 2617440
# 2                 7578.639593                 1006989
# ...

# %% [markdown]
# ### 2. Checking for Any Null Values

# %% [markdown]
# The best way to check for Null values is using the .isnull() method and then summing them (rather than having to find and count up all the Trues). This is a critical step because for our eventual analysis, many of our methods will run into errors and require debugging if it encounters any null values.

# %%
#2 Check for missing values (null):
sat_2018.isnull().sum()
# Out:
# State                                 0
# Participation                         0
# Evidence-Based Reading and Writing    0
# Math                                  0
# Total                                 0
# dtype: int64

# %%
#2 Check for missing values (null):
act_2018.isnull().sum()
# Out:
# State            0
# Participation    0
# Composite        0
# dtype: int64

# %%
#2 Check for missing values (null):
act_2018.isnull().sum()
# Out:
# State            0
# Participation    0
# Composite        0
# dtype: int64

# %% [markdown]
# ### 3. Checking For Any Clearly 'Wrong' Data

# %% [markdown]
# .Describe() is the clearest way to run through our data and see if there's anything that looks out of order. We will be given a summary stastic for the entire data set and will be able to draw any conclusions and inspect any observances that would be throwing our entire set out of order. **Careful of outliers, don't want to remove them**

# %%
#3 Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest)
sat_2018.describe()
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           563.686275  556.235294  1120.019608
# std                             47.502627   47.772623    94.155083
# min                            480.000000  480.000000   977.000000
# 25%                            534.500000  522.500000  1057.500000
# 50%                            552.000000  544.000000  1098.000000
# 75%                            610.500000  593.500000  1204.000000
# max                            643.000000  655.000000  1298.000000

# %%
#3. Observation issues:
act_2018.describe()
# Out:
#        Composite
# count  52.000000
# mean   21.544231
# std     2.119417
# min    17.700000
# 25%    19.975000
# 50%    21.300000
# 75%    23.725000
# max    25.600000

# %%
#3. Observation issues:
state_funding_2018.describe()
# Out:
#        Total  Spending Per Pupil  Total Spending  \
# count                  52.000000    5.200000e+01
# mean                12910.614543    2.772865e+07
# std                  3813.287769    9.963016e+07
# min                  7627.660095    1.507836e+06
# 25%                 10122.364191    3.400130e+06
# 50%                 12067.744230    8.466324e+06
# 75%                 15341.159080    1.700502e+07
# max                 24039.921492    7.209450e+08
#
#        Instruction Spending Per Pupil  Total Instruction Spending  \
# count                       52.000000                5.200000e+01
# mean                      7709.278268                1.471093e+07
# std                       2481.498219                5.290237e+07
# min                       4440.787784                7.142850e+05
# 25%                       5873.926597                1.758911e+06
# 50%                       7144.223630                4.208112e+06
# ...

# %% [markdown]
# ### 4. Fixing Missing or Eroneous Data

# %% [markdown]
# Data looks pretty clean! Next step is cleaning up the columns and data types that will allow us to merge and work with our set properly.

# %%
#4. Did not identify any null values for the three datasets
# Did not identify any clearly wrong errors within our dataset relating to min or max (incorrect/not possible data)

# %% [markdown]
# ### 5. Displaying Datatypes

# %% [markdown]
# As indicated, we want to make sure that any numerical column we plan to use in our analyze is the correct datatype (either int or float). If we see that a column is an object when it should be numerical we will have to find a way to convert it.

# %%
#5. Display Datatypes:
sat_2018.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
#5. Display Datatypes:
act_2018.dtypes
# Out:
# State             object
# Participation     object
# Composite        float64
# dtype: object

# %%
#5. Display Datatypes:
state_funding_2018.dtypes
# Out:
# Geographic Area                    object
# Total  Spending Per Pupil         float64
# Total Spending                      int64
# Instruction Spending Per Pupil    float64
# Total Instruction Spending          int64
# Support Spending Per Pupil        float64
# Total Support Spending              int64
# dtype: object

# %% [markdown]
# ### 6. Mapping Percent Strings to Floats

# %% [markdown]
# Time to make good on our commitment to clean frames, convert the percent strings into usable floats!

# %%
#6. Will have to fix the 'Participation' rates for both act and sat datasets

# %%
#6. act map:
act_2018['Participation'] = act_2018['Participation'].map(percent_to_float)

# %%
act_2018.head()
# Out:
#         State  Participation  Composite
# 0     Alabama           1.00       19.1
# 1      Alaska           0.33       20.8
# 2     Arizona           0.66       19.2
# 3    Arkansas           1.00       19.4
# 4  California           0.27       22.7

# %%
#6. sat map:
sat_2018['Participation'] = sat_2018['Participation'].map(percent_to_float)

# %%
sat_2018.head()
# Out:
#         State  Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama           0.06                                 595   571   1166
# 1      Alaska           0.43                                 562   544   1106
# 2     Arizona           0.29                                 577   572   1149
# 3    Arkansas           0.05                                 592   576   1169
# 4  California           0.60                                 540   536   1076

# %% [markdown]
# ### 7. Lowercasing Columns and Underscoring Spaces

# %% [markdown]
# Putting our columns in lowercase is proper python format and removing any spaces will allow us to call different columns with the .column method as noted in the instructions

# %%
#7. Lowercasing all columns and replacing spaces with '_'
state_funding_2018.columns = state_funding_2018.columns.str.lower().str.replace(' ', '_')

# %%
state_funding_2018.head()
# Out:
#   geographic_area  total__spending_per_pupil  total_spending  \
# 0  -United States               12611.842660       720944995
# 1         Alabama                9696.181213         8068664
# 2          Alaska               17725.939250         2526833
# 3         Arizona                8238.534796         8861562
# 4        Arkansas               10138.680596         5562235
#
#    instruction_spending_per_pupil  total_instruction_spending  \
# 0                     7649.510417                   382484159
# 1                     5520.600270                     4102597
# 2                     9495.439220                     1261678
# 3                     4440.787784                     4126812
# 4                     5723.209691                     2750549
#
#    support_spending_per_pupil  total_support_spending
# 0                 4457.058229               216533516
# 1                 3526.601356                 2617440
# 2                 7578.639593                 1006989
# ...

# %%
#7. Lowercasing all columns and replacing spaces with '_'
act_2018.columns = act_2018.columns.str.lower().str.replace(' ', '_')

# %%
act_2018.head()
# Out:
#         state  participation  composite
# 0     Alabama           1.00       19.1
# 1      Alaska           0.33       20.8
# 2     Arizona           0.66       19.2
# 3    Arkansas           1.00       19.4
# 4  California           0.27       22.7

# %%
#7. Lowercasing all columns and replacing spaces with '_' (and shortening to ebrw)
sat_2018.columns = sat_2018.columns.str.lower().str.replace(' ', '_')
sat_2018.rename(columns = {'evidence-based_reading_and_writing': 'ebrw'}, inplace = True)

# %%
sat_2018.head()
# Out:
#         state  participation  ebrw  math  total
# 0     Alabama           0.06   595   571   1166
# 1      Alaska           0.43   562   544   1106
# 2     Arizona           0.29   577   572   1149
# 3    Arkansas           0.05   592   576   1169
# 4  California           0.60   540   536   1076

# %% [markdown]
# ### 8. Dropping Unnecessary Rows for Merge Prep

# %% [markdown]
# Check for any duplicate data rows that we missed in our initial clean. In order to properly merge our data sets we want to be able to combine them correctly and accurately, this means all rows must line up!

# %%
#8. Before merging let's make sure our rows matchup: print shape for all datasets
print(sat_2018.shape)
print(act_2018.shape)
print(state_funding_2018.shape)
#We see that act has duplicate entry for 'Maine' and that funding has an entry for the 
#US as a whole, which we will not need and allow us to merge all three data sets into one
# Out:
# (51, 5)
# (52, 3)
# (52, 7)

# %%
#drop Maine duplicate in act_2018
act_2018.drop_duplicates(inplace=True)
act_2018.shape
# Out:
# (51, 3)

# %%
#with help from: https://stackoverflow.com/questions/43136137/drop-a-specific-row-in-pandas
i = state_funding_2018[state_funding_2018['geographic_area'] == '-United States'].index
state_funding_2018.drop(i, inplace = True)
state_funding_2018.shape
# Out:
# (51, 7)

# %%
#before merging we want to make sure that we have a common column to merge with: state
#So let's rename 'geographic_area' to 'state' for state_funding df
state_funding_2018.rename(columns = {'geographic_area': 'state', 'total__spending_per_pupil': 'total_spending_per_pupil'}, inplace = True)

# %%
state_funding_2018.head()
# Out:
#         state  total_spending_per_pupil  total_spending  \
# 1     Alabama               9696.181213         8068664
# 2      Alaska              17725.939250         2526833
# 3     Arizona               8238.534796         8861562
# 4    Arkansas              10138.680596         5562235
# 5  California              12497.686029        92047964
#
#    instruction_spending_per_pupil  total_instruction_spending  \
# 1                     5520.600270                     4102597
# 2                     9495.439220                     1261678
# 3                     4440.787784                     4126812
# 4                     5723.209691                     2750549
# 5                     7426.337273                    46143126
#
#    support_spending_per_pupil  total_support_spending
# 1                 3526.601356                 2617440
# 2                 7578.639593                 1006989
# 3                 3350.778206                 3078628
# ...

# %%
state_funding_2018.columns
# Out:
# Index(['state', 'total_spending_per_pupil', 'total_spending',
#        'instruction_spending_per_pupil', 'total_instruction_spending',
#        'support_spending_per_pupil', 'total_support_spending'],
#       dtype='object')

# %%
#Also prior to merging, let's drop some unnecessary columns from state funding, we will leave our 
#interested column 'spending per pupil'. In case we want to circle back to other columns let's save it into a new
#variable dataframe
to_drop = ['total_spending',
       'instruction_spending_per_pupil', 'total_instruction_spending',
       'support_spending_per_pupil', 'total_support_spending']
state_funding_2018_drops = state_funding_2018.drop(columns = to_drop)

# %%
#Let's also round our dollar amounts to easier to work with numbers and round to the nearest dollar:
state_funding_2018_drops=state_funding_2018_drops.round(0)

# %%
state_funding_2018_drops.head()
# Out:
#         state  total_spending_per_pupil
# 1     Alabama                    9696.0
# 2      Alaska                   17726.0
# 3     Arizona                    8239.0
# 4    Arkansas                   10139.0
# 5  California                   12498.0

# %% [markdown]
# ### 9. Merge Dataframes

# %% [markdown]
# TIME TO MERGE! After this we will be left with our main dataframe that we can work out of during our analysis

# %%
#Now we should finally be able to merge all of frames together into one centralized dataframe:
act_sat_merge=pd.merge(sat_2018, act_2018, on='state')
merged_df=pd.merge(act_sat_merge, state_funding_2018_drops, on='state')
merged_df.head()
# Out:
#         state  participation_x  ebrw  math  total  participation_y  composite  \
# 0     Alabama             0.06   595   571   1166             1.00       19.1
# 1      Alaska             0.43   562   544   1106             0.33       20.8
# 2     Arizona             0.29   577   572   1149             0.66       19.2
# 3    Arkansas             0.05   592   576   1169             1.00       19.4
# 4  California             0.60   540   536   1076             0.27       22.7
#
#    total_spending_per_pupil
# 0                    9696.0
# 1                   17726.0
# 2                    8239.0
# 3                   10139.0
# 4                   12498.0

# %% [markdown]
# ### 10. Additional Cleaning:

# %% [markdown]
# A bit more tidying up of column names and anything else that may need fixing that resulted from the big merge

# %%
#Let's clean up our column names a bit:
merged_df.rename(columns={'participation_x': 'sat_participation', 'participation_y': 'act_participation',
                         'total': 'sat_total', 'composite':'act_score'}, inplace=True)
merged_df.head()
# Out:
#         state  sat_participation  ebrw  math  sat_total  act_participation  \
# 0     Alabama               0.06   595   571       1166               1.00
# 1      Alaska               0.43   562   544       1106               0.33
# 2     Arizona               0.29   577   572       1149               0.66
# 3    Arkansas               0.05   592   576       1169               1.00
# 4  California               0.60   540   536       1076               0.27
#
#    act_score  total_spending_per_pupil
# 0       19.1                    9696.0
# 1       20.8                   17726.0
# 2       19.2                    8239.0
# 3       19.4                   10139.0
# 4       22.7                   12498.0

# %% [markdown]
# ### 11. Saving Our New Dataframe to .csv

# %% [markdown]
# Lastly, let's save our merged frame into a csv for any potential future use!

# %%
merged_df.to_csv(f'{path}/merged_act_sat_funding.csv')

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**
#
# *Note*: if you are unsure of what a feature is, check the source of the data! This can be found in the README.

# %% [markdown]
# **To-Do:** *Edit the table below to create your own data dictionary for the datasets you chose.*
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state|object|2018 ACT/ACT/Public School Spending Per Student By State|Indicates the specific state of the country|
# |sat_participation|float|2018 SAT| The reported participation rate of pupil's that took the SAT across the state|
# |ebrw|int|2018 SAT|The statewide average score for the Evidence-Based Reading and Writing section of the SAT|
# |math|int|2018 SAT|The statewide average score for the Math section of the SAT|
# |sat_total|int|2018 SAT|The combined (total) statewide average score for the entire SAT|
# |act_participation|float|2018 ACT| The reported participation rate of pupil's that took the ACT across the state|
# |act_total|int|2018 ACT|The reported statewide average score for the ACT exam|
# |total_spending_per_pupil|float|2018 Public School Spending Per Student By State|How much total money is spent on public education per student|
# |total_spending|int|2018 Public School Spending Per Student By State|Total amount of public education spending per state|
# |instruction_spending_per_pupil|float|2018 Public School Spending Per Student By State|How much money is spent on salaries for teachers and teacher aides, textbooks, supplies and purchased services per student|
# |total_instruction_spending|int|2018 Public School Spending Per Student By State|How much money is spent on salaries for teachers and teacher aides, textbooks, supplies and purchased services in total per state|
# |support_spending_per_pupil|float|2018 Public School Spending Per Student By State|How much money is spent on adminstrative expenses and support staff per student|
# |total_support_spending|int|2018 Public School Spending Per Student By State|How much money is spent on adminstrative expenses and support staff in total per state|

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %% [markdown]
# ### 1. Summary Statistics

# %%
merged_df.describe()
# Out:
#        sat_participation        ebrw        math    sat_total  \
# count          50.000000   50.000000   50.000000    50.000000
# mean            0.448200  565.020000  557.760000  1122.880000
# std             0.370976   47.010416   46.987432    92.845634
# min             0.020000  480.000000  486.000000   998.000000
# 25%             0.042500  535.000000  524.250000  1062.250000
# 50%             0.500000  552.000000  545.500000  1098.500000
# 75%             0.745000  612.750000  594.250000  1207.000000
# max             1.000000  643.000000  655.000000  1298.000000
#
#        act_participation  act_score  total_spending_per_pupil
# count          50.000000  50.000000                 50.000000
# mean            0.623200  21.454000              12719.700000
# std             0.341141   2.111312               3621.636023
# min             0.070000  17.700000               7628.000000
# 25%             0.277500  19.925000              10089.500000
# ...

# %% [markdown]
# ### 2. Std. Dev Through Dictionary Comprehension

# %%
#from Part 1
def std_calculator(x):
    average = mean_calculator(x)
    count = 0
    for i in x:
        count += (i-average)**2
    return (count/len(x))**.5

# %%
merged_df.head()
# Out:
#         state  sat_participation  ebrw  math  sat_total  act_participation  \
# 0     Alabama               0.06   595   571       1166               1.00
# 1      Alaska               0.43   562   544       1106               0.33
# 2     Arizona               0.29   577   572       1149               0.66
# 3    Arkansas               0.05   592   576       1169               1.00
# 4  California               0.60   540   536       1076               0.27
#
#    act_score  total_spending_per_pupil
# 0       19.1                    9696.0
# 1       20.8                   17726.0
# 2       19.2                    8239.0
# 3       19.4                   10139.0
# 4       22.7                   12498.0

# %%
#Code:
num_cols = merged_df.drop(columns = 'state')
num_cols.head()
# Out:
#    sat_participation  ebrw  math  sat_total  act_participation  act_score  \
# 0               0.06   595   571       1166               1.00       19.1
# 1               0.43   562   544       1106               0.33       20.8
# 2               0.29   577   572       1149               0.66       19.2
# 3               0.05   592   576       1169               1.00       19.4
# 4               0.60   540   536       1076               0.27       22.7
#
#    total_spending_per_pupil
# 0                    9696.0
# 1                   17726.0
# 2                    8239.0
# 3                   10139.0
# 4                   12498.0

# %%
num_cols.columns
# Out:
# Index(['sat_participation', 'ebrw', 'math', 'sat_total', 'act_participation',
#        'act_score', 'total_spending_per_pupil'],
#       dtype='object')

# %%
keys = ['sat_participation', 'ebrw', 'math', 'sat_total', 'act_participation',
       'act_score', 'total_spending_per_pupil']
values = [std_calculator(num_cols[i]) for i in keys]

# %%
sd = {i:j for (i,j) in zip(keys, values)}

# %%
sd
# Out:
# {'sat_participation': 0.36724754594142633,
#  'ebrw': 46.537937212558106,
#  'math': 46.51518461749884,
#  'sat_total': 91.9124888140888,
#  'act_participation': 0.33771254048376703,
#  'act_score': 2.090091864009809,
#  'total_spending_per_pupil': 3585.2367467156205}

# %%
#with assistance from: https://www.listendata.com/2019/07/python-dictionary-comprehension.html

# %% [markdown]
# ### 3. Investigating Trends

# %% [markdown]
# #### Before investigating deeper into our correlation between per pupil spending and the responding tests scores, it is imoprtant that we first take a look at participation rates for each exam to make sure that we compare significant data along with the comparing the appropriate scores

# %%
merged_df.head()
# Out:
#         state  sat_participation  ebrw  math  sat_total  act_participation  \
# 0     Alabama               0.06   595   571       1166               1.00
# 1      Alaska               0.43   562   544       1106               0.33
# 2     Arizona               0.29   577   572       1149               0.66
# 3    Arkansas               0.05   592   576       1169               1.00
# 4  California               0.60   540   536       1076               0.27
#
#    act_score  total_spending_per_pupil
# 0       19.1                    9696.0
# 1       20.8                   17726.0
# 2       19.2                    8239.0
# 3       19.4                   10139.0
# 4       22.7                   12498.0

# %%
#Sorting by top 20 participation rates for respective exams:

# %%
#Top 20 States with ACT Participation Rates:
merged_df.sort_values('act_participation', ascending = False).head(20)
# Out:
#              state  sat_participation  ebrw  math  sat_total  \
# 0          Alabama               0.06   595   571       1166
# 16        Kentucky               0.04   630   618       1248
# 48       Wisconsin               0.03   641   653       1294
# 43            Utah               0.04   480   530       1010
# 41       Tennessee               0.06   624   607       1231
# 39  South Carolina               0.55   547   523       1070
# 35            Ohio               0.18   552   547       1099
# 34        Oklahoma               0.08   541   521       1062
# 32  North Carolina               0.52   554   543       1098
# 27          Nevada               0.23   574   566       1140
# 26        Nebraska               0.03   629   623       1252
# 24        Missouri               0.04   633   629       1262
# 23     Mississippi               0.03   630   606       1236
# 17       Louisiana               0.04   615   595       1210
# ...

# %% [markdown]
# Trend: As we can see from the above dataframe sorted by ACT Participation rates, there are 17 states that have a 100% participation rate for the ACTs. It would seem that there is a regional trend and that the ACTs are most popular among southern and midwest states.

# %%
#Top 20 States with SAT Participation Rates:
merged_df.sort_values('sat_participation', ascending = False).head(20)
# Out:
#             state  sat_participation  ebrw  math  sat_total  \
# 11          Idaho               1.00   508   493       1001
# 5        Colorado               1.00   519   506       1025
# 6     Connecticut               1.00   535   519       1053
# 7        Delaware               1.00   505   492        998
# 21       Michigan               1.00   511   499       1011
# 18          Maine               0.99   512   501       1013
# 12       Illinois               0.99   513   506       1019
# 38   Rhode Island               0.97   513   505       1018
# 28  New Hampshire               0.96   535   528       1063
# 29     New Jersey               0.82   547   547       1094
# 20  Massachusetts               0.80   562   563       1125
# 31       New York               0.79   534   534       1068
# 19       Maryland               0.76   545   535       1080
# 9         Georgia               0.70   542   522       1064
# 37   Pennsylvania               0.70   547   539       1086
# ...

# %% [markdown]
# Trend: Inversely there are only 5 states with 100% participation rates for the SATs and with a bit of outside research we can discover this is due to these states having mandatory SAT testing required by their students. Apart from those mandatory states it seems there is a trending for the coastal states to be the ones favoring the SATs over the ACTs

# %%
#Create a function to sort out different participation rates using masks:
def participation_combos(sat_part , act_part):
    result=merged_df[(merged_df['sat_participation'] >= sat_part) & (merged_df['act_participation'] >= act_part)]
    return result

# %%
#Are there any states with at least 50% participation rates for both exams?
participation_combos(.50, .50)
# Out:
#              state  sat_participation  ebrw  math  sat_total  \
# 8          Florida               0.56   550   549       1099
# 9          Georgia               0.70   542   522       1064
# 10          Hawaii               0.56   480   530       1010
# 32  North Carolina               0.52   554   543       1098
# 39  South Carolina               0.55   547   523       1070
#
#     act_participation  act_score  total_spending_per_pupil
# 8                0.66       19.9                    9346.0
# 9                0.53       21.4                   10810.0
# 10               0.89       18.9                   15242.0
# 32               1.00       19.1                    9377.0
# 39               1.00       18.3                   10856.0

# %% [markdown]
# Finding: As we can see from our result, there don't seem to be many states that take both exams at a rate of at least 50% for both. From this we will want to keep in mind with our final analysis to note that we should make sure we are comparing our data against the more popular of the test for each state. We will still look at the correlation of spending per pupil against each exam, but the findings will be more telling if we group our data into two subsets: 'act preferred' and 'sat preferred'

# %% [markdown]
# ###### Disclaimer: Term usage of "preferred" does not apply to specific students preference and choice it refers simply to a state recording a higher participation rate in one exam over the other

# %%
act_preferred = merged_df[merged_df['sat_participation'] < merged_df['act_participation']]
sat_preferred = merged_df[merged_df['sat_participation'] > merged_df['act_participation']]

# %%
print(act_preferred.shape)
act_preferred.head()
# Out:
# (27, 8)
#        state  sat_participation  ebrw  math  sat_total  act_participation  \
# 0    Alabama               0.06   595   571       1166               1.00
# 2    Arizona               0.29   577   572       1149               0.66
# 3   Arkansas               0.05   592   576       1169               1.00
# 8    Florida               0.56   550   549       1099               0.66
# 10    Hawaii               0.56   480   530       1010               0.89
#
#     act_score  total_spending_per_pupil
# 0        19.1                    9696.0
# 2        19.2                    8239.0
# 3        19.4                   10139.0
# 8        19.9                    9346.0
# 10       18.9                   15242.0

# %%
print(sat_preferred.shape)
sat_preferred.head()
# Out:
# (23, 8)
#          state  sat_participation  ebrw  math  sat_total  act_participation  \
# 1       Alaska               0.43   562   544       1106               0.33
# 4   California               0.60   540   536       1076               0.27
# 5     Colorado               1.00   519   506       1025               0.30
# 6  Connecticut               1.00   535   519       1053               0.26
# 7     Delaware               1.00   505   492        998               0.17
#
#    act_score  total_spending_per_pupil
# 1       20.8                   17726.0
# 4       22.7                   12498.0
# 5       23.9                   10202.0
# 6       25.6                   20635.0
# 7       23.8                   15639.0

# %% [markdown]
# Findings: From our now filtered sets we can see that there are 27 states that have higher act_participation rates and inversely there are 23 states with higher sat participation rates. This will come in handy when creating more significant correlations through our visualizations.

# %% [markdown]
# #### Next let's sort our scores as well as spending per pupil (and apply to our sorted sets as well)

# %%
#States with top 20 SAT Scores (Nationwide):
top_sat_nation = merged_df.sort_values('sat_total', ascending = False).head(20)
top_sat_nation
# Out:
#             state  sat_participation  ebrw  math  sat_total  \
# 22      Minnesota               0.04   643   655       1298
# 48      Wisconsin               0.03   641   653       1294
# 33   North Dakota               0.02   640   643       1283
# 14           Iowa               0.03   634   631       1265
# 15         Kansas               0.04   633   631       1265
# 24       Missouri               0.04   633   629       1262
# 49        Wyoming               0.03   633   625       1257
# 26       Nebraska               0.03   629   623       1252
# 16       Kentucky               0.04   630   618       1248
# 40   South Dakota               0.03   622   618       1240
# 23    Mississippi               0.03   630   606       1236
# 41      Tennessee               0.06   624   607       1231
# 17      Louisiana               0.04   615   595       1210
# 25        Montana               0.10   606   592       1198
# 3        Arkansas               0.05   592   576       1169
# ...

# %%
#States with top 20 SAT Scores (Sat Preferred Set):
top_scores_sat_pref = sat_preferred.sort_values('sat_total', ascending = False).head(20)
top_scores_sat_pref
# Out:
#             state  sat_participation  ebrw  math  sat_total  \
# 20  Massachusetts               0.80   562   563       1125
# 44        Vermont               0.64   565   554       1120
# 36         Oregon               0.48   564   553       1117
# 45       Virginia               0.68   567   550       1117
# 1          Alaska               0.43   562   544       1106
# 29     New Jersey               0.82   547   547       1094
# 37   Pennsylvania               0.70   547   539       1086
# 46     Washington               0.69   543   538       1081
# 19       Maryland               0.76   545   535       1080
# 4      California               0.60   540   536       1076
# 13        Indiana               0.63   542   532       1074
# 31       New York               0.79   534   534       1068
# 9         Georgia               0.70   542   522       1064
# 28  New Hampshire               0.96   535   528       1063
# 6     Connecticut               1.00   535   519       1053
# ...

# %% [markdown]
# Findings: Very interesting to note the differences in the two above sets. In our original set, Mass ranked 19th nationwide in SAT scores, but in our filtered preferred set they ranked 1st. This might lead us to believe that small percentage of students that do take the SATs are among the top students of their states (resulting in the much higher scores).

# %%
#States with top 20 ACT Scores (Nationwide):
top_act_nation=merged_df.sort_values('act_score', ascending = False).head(20)
top_act_nation
# Out:
#             state  sat_participation  ebrw  math  sat_total  \
# 6     Connecticut               1.00   535   519       1053
# 20  Massachusetts               0.80   562   563       1125
# 28  New Hampshire               0.96   535   528       1063
# 31       New York               0.79   534   534       1068
# 21       Michigan               1.00   511   499       1011
# 38   Rhode Island               0.97   513   505       1018
# 44        Vermont               0.64   565   554       1120
# 18          Maine               0.99   512   501       1013
# 45       Virginia               0.68   567   550       1117
# 12       Illinois               0.99   513   506       1019
# 5        Colorado               1.00   519   506       1025
# 7        Delaware               1.00   505   492        998
# 29     New Jersey               0.82   547   547       1094
# 37   Pennsylvania               0.70   547   539       1086
# 4      California               0.60   540   536       1076
# ...

# %%
#States with top 20 ACT Scores (ACT Preferred):
top_scores_act_pref=act_preferred.sort_values('act_score', ascending = False).head(20)
top_scores_act_pref
# Out:
#             state  sat_participation  ebrw  math  sat_total  \
# 40   South Dakota               0.03   622   618       1240
# 14           Iowa               0.03   634   631       1265
# 15         Kansas               0.04   633   631       1265
# 22      Minnesota               0.04   643   655       1298
# 48      Wisconsin               0.03   641   653       1294
# 43           Utah               0.04   480   530       1010
# 47  West Virginia               0.28   513   486        999
# 35           Ohio               0.18   552   547       1099
# 33   North Dakota               0.02   640   643       1283
# 16       Kentucky               0.04   630   618       1248
# 26       Nebraska               0.03   629   623       1252
# 25        Montana               0.10   606   592       1198
# 49        Wyoming               0.03   633   625       1257
# 24       Missouri               0.04   633   629       1262
# 8         Florida               0.56   550   549       1099
# ...

# %% [markdown]
# Findings: We can see similar results in our ACT sorting as we did with SATs once we set a masks of 'preference' (higher participation rates). Although for our nationwide findings our rates are much closer than what we observed in the nationwide SAT sorted scores.

# %% [markdown]
# #### Finally Let's Sort Our Data by Spending Per Pupil

# %%
#Top 20 States with Highest Funding Per Pupil (Nationwide):
top_spending_nation = merged_df.sort_values('total_spending_per_pupil', ascending = False).head(20)
top_spending_nation
# Out:
#             state  sat_participation  ebrw  math  sat_total  \
# 31       New York               0.79   534   534       1068
# 6     Connecticut               1.00   535   519       1053
# 29     New Jersey               0.82   547   547       1094
# 44        Vermont               0.64   565   554       1120
# 1          Alaska               0.43   562   544       1106
# 20  Massachusetts               0.80   562   563       1125
# 28  New Hampshire               0.96   535   528       1063
# 37   Pennsylvania               0.70   547   539       1086
# 49        Wyoming               0.03   633   625       1257
# 38   Rhode Island               0.97   513   505       1018
# 12       Illinois               0.99   513   506       1019
# 7        Delaware               1.00   505   492        998
# 10         Hawaii               0.56   480   530       1010
# 19       Maryland               0.76   545   535       1080
# 18          Maine               0.99   512   501       1013
# ...

# %%
#For consistency let's apply Top 10 Spending Per Pupil on our 'preferred' subsets:
#SAT Preferred:
top_spend_sat = sat_preferred.sort_values('total_spending_per_pupil', ascending = False).head(10)
top_spend_sat
# Out:
#             state  sat_participation  ebrw  math  sat_total  \
# 31       New York               0.79   534   534       1068
# 6     Connecticut               1.00   535   519       1053
# 29     New Jersey               0.82   547   547       1094
# 44        Vermont               0.64   565   554       1120
# 1          Alaska               0.43   562   544       1106
# 20  Massachusetts               0.80   562   563       1125
# 28  New Hampshire               0.96   535   528       1063
# 37   Pennsylvania               0.70   547   539       1086
# 38   Rhode Island               0.97   513   505       1018
# 12       Illinois               0.99   513   506       1019
#
#     act_participation  act_score  total_spending_per_pupil
# 31               0.27       24.5                   24040.0
# 6                0.26       25.6                   20635.0
# 29               0.31       23.7                   20021.0
# 44               0.24       24.1                   19340.0
# ...

# %%
#SAT Preferred:
top_spend_act = act_preferred.sort_values('total_spending_per_pupil', ascending = False).head(10)
top_spend_act
# Out:
#            state  sat_participation  ebrw  math  sat_total  act_participation  \
# 49       Wyoming               0.03   633   625       1257               1.00
# 10        Hawaii               0.56   480   530       1010               0.89
# 33  North Dakota               0.02   640   643       1283               0.98
# 35          Ohio               0.18   552   547       1099               1.00
# 22     Minnesota               0.04   643   655       1298               0.99
# 26      Nebraska               0.03   629   623       1252               1.00
# 48     Wisconsin               0.03   641   653       1294               1.00
# 14          Iowa               0.03   634   631       1265               0.68
# 25       Montana               0.10   606   592       1198               1.00
# 15        Kansas               0.04   633   631       1265               0.71
#
#     act_score  total_spending_per_pupil
# 49       20.0                   16224.0
# ...

# %% [markdown]
# Findings: Not much to determine yet, but it is interesting to note that the states that have higher act participation rates generally are states with lower spending per pupil. As we can see the state with the highest spending per pupil of the act 'preferred' states ranks 9th amongst the sat 'preferred' set. (The next highest on that list isn't even in the top 10).

# %% [markdown]
# #### Observing Intersection in Our Data: Will We Find The States With Higher Spending Per Pupil Amongst the Lists With The Higher Scores?

# %%
#Let's first check our nationwide SAT scores against our Nationwide Per Pupil
int_df = pd.merge(top_sat_nation, top_spending_nation, how = 'inner')
int_df
# Out:
#            state  sat_participation  ebrw  math  sat_total  act_participation  \
# 0      Minnesota               0.04   643   655       1298               0.99
# 1   North Dakota               0.02   640   643       1283               0.98
# 2        Wyoming               0.03   633   625       1257               1.00
# 3  Massachusetts               0.80   562   563       1125               0.25
# 4        Vermont               0.64   565   554       1120               0.24
#
#    act_score  total_spending_per_pupil
# 0       21.3                   12975.0
# 1       20.3                   13758.0
# 2       20.0                   16224.0
# 3       25.5                   17058.0
# 4       24.1                   19340.0

# %%
#More appropriaely let's check funding agains SAT Preferred
int_df_1 = pd.merge(top_scores_sat_pref, top_spending_nation, how = 'inner')
int_df_1
# Out:
#             state  sat_participation  ebrw  math  sat_total  \
# 0   Massachusetts               0.80   562   563       1125
# 1         Vermont               0.64   565   554       1120
# 2          Alaska               0.43   562   544       1106
# 3      New Jersey               0.82   547   547       1094
# 4    Pennsylvania               0.70   547   539       1086
# 5      Washington               0.69   543   538       1081
# 6        Maryland               0.76   545   535       1080
# 7      California               0.60   540   536       1076
# 8        New York               0.79   534   534       1068
# 9   New Hampshire               0.96   535   528       1063
# 10    Connecticut               1.00   535   519       1053
# 11       Illinois               0.99   513   506       1019
# 12   Rhode Island               0.97   513   505       1018
# 13          Maine               0.99   512   501       1013
#
#     act_participation  act_score  total_spending_per_pupil
# ...

# %% [markdown]
# ##### Trend: Here we can see from above that of the SAT preferred, we register 14 of the top 20 spending per pupil states on this list.

# %%
#Similarly let's conduct the same comparison for ACT to Funding:
int_df_2 = pd.merge(top_act_nation, top_spending_nation, how = 'inner')
int_df_2
# Out:
#             state  sat_participation  ebrw  math  sat_total  \
# 0     Connecticut               1.00   535   519       1053
# 1   Massachusetts               0.80   562   563       1125
# 2   New Hampshire               0.96   535   528       1063
# 3        New York               0.79   534   534       1068
# 4    Rhode Island               0.97   513   505       1018
# 5         Vermont               0.64   565   554       1120
# 6           Maine               0.99   512   501       1013
# 7        Illinois               0.99   513   506       1019
# 8        Delaware               1.00   505   492        998
# 9      New Jersey               0.82   547   547       1094
# 10   Pennsylvania               0.70   547   539       1086
# 11     California               0.60   540   536       1076
# 12       Maryland               0.76   545   535       1080
# 13     Washington               0.69   543   538       1081
#
#     act_participation  act_score  total_spending_per_pupil
# ...

# %% [markdown]
# ###### Again we see a correlation between more spending and top scores. 14 of the 20 top ACT recorded states all reside in the top 20 of spending per pupil nationally

# %%
#Once more but against ACT preferred:
int_df_3 = pd.merge(top_scores_act_pref, top_spending_nation, how = 'inner')
int_df_3
# Out:
#           state  sat_participation  ebrw  math  sat_total  act_participation  \
# 0     Minnesota               0.04   643   655       1298               0.99
# 1          Ohio               0.18   552   547       1099               1.00
# 2  North Dakota               0.02   640   643       1283               0.98
# 3       Wyoming               0.03   633   625       1257               1.00
#
#    act_score  total_spending_per_pupil
# 0       21.3                   12975.0
# 1       20.3                   13027.0
# 2       20.3                   13758.0
# 3       20.0                   16224.0

# %% [markdown]
# **To-Do:** *Edit this cell with your findings on trends in the data (step 3 above).*
# See Markdowns for each individual step for observed trends from each cut

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %% [markdown]
# ### Seaborn Heatmap for Merged Set

# %%
corr = merged_df.corr()
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
plt.figure(figsize=(9, 9))
plt.title('Corresponding Element Relationships: Merged Data')
sns.heatmap(corr, annot=True,
            cmap='coolwarm', vmin=-1, vmax=1);

# %%
corr = merged_df.corr()
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
plt.figure(figsize=(9, 9))
plt.title('Corresponding Element Relationships: Merged Data')
sns.heatmap(corr, annot=True,
            cmap='coolwarm', vmin=-1, vmax=1, mask=mask);

# %% [markdown]
# ### Histograms

# %%
merged_df.hist(figsize=(12, 12));

# %% [markdown]
# #### A Closer Look at Some of The Histograms:

# %%
plt.figure(figsize=(12, 6))
plt.hist(merged_df['total_spending_per_pupil'], bins=10)
plt.title('Distribution of Spending Per Pupil')
plt.xlabel('Dollars Spent Per Pupil')
plt.ylabel('Number of States');

# %% [markdown]
# ##### For our above histogram looking at Dollars Spent Per Pupil we resulted in a right skewed histogram. This means that our mean will be measured higher than our median.

# %%
#Now let's look at at a histogram of our preferred datasets: SAT Scores for SAT Preferred States:
plt.figure(figsize=(12, 6))
plt.hist(sat_preferred['sat_total'], bins=9)
plt.title('Distribution of SAT Scores (SAT Preferred States)')
plt.xlabel('SAT Scores')
plt.ylabel('Number of States');

# %%
#Let's compare it to our national distributions:
plt.figure(figsize=(12, 6))
plt.hist(merged_df['sat_total'], bins=9)
plt.title('Distribution of SAT Scores (Nationwide)')
plt.xlabel('SAT Scores')
plt.ylabel('Number of States');

# %% [markdown]
# ### Boxplots

# %%
merged_df['total_spending_per_pupil'].describe()
# Out:
# count       50.000000
# mean     12719.700000
# std       3621.636023
# min       7628.000000
# 25%      10089.500000
# 50%      11826.000000
# 75%      15122.000000
# max      24040.000000
# Name: total_spending_per_pupil, dtype: float64

# %%
sns.boxplot(x = merged_df['total_spending_per_pupil'])
plt.title('Distribution of Spending Per Pupil');

# %% [markdown]
# Interpretation: I always find it useful to have the describe summary up when looking at boxplots. Boxplots are useful visual representations of spread of data in relation to our quartiles. We can see here that the 25th percentile is around the $10,000 spending mark, while the 75th percentile is at $15,122. If we compare this to our earlier right skewed histogram this would make sense in terms of our data distribution for this feature.

# %%
merged_df['act_score'].describe()
# Out:
# count    50.000000
# mean     21.454000
# std       2.111312
# min      17.700000
# 25%      19.925000
# 50%      21.050000
# 75%      23.650000
# max      25.600000
# Name: act_score, dtype: float64

# %%
sns.boxplot(x = merged_df['act_score'])
plt.title('Distribution of ACT Scores Nationwide');

# %% [markdown]
# Compare this to our histogram and we can see that while the percentiles seem to be more evenly balanced our average is skewed closer to the 25th percentile. This is a result of being somewhat right skewed to a degree but also having a spike in higher scores in some states

# %%
act_preferred['act_score'].describe()
# Out:
# count    27.000000
# mean     19.866667
# std       1.018672
# min      17.700000
# 25%      19.200000
# 50%      20.000000
# 75%      20.300000
# max      21.900000
# Name: act_score, dtype: float64

# %%
sns.boxplot(x = act_preferred['act_score'])
plt.title('Distribution of ACT Scores (ACT Preferred)');

# %% [markdown]
# If we then boxplot the same ACT scores with the states that participate more in the ACT our average goes down, but we see a a smaller variance in our percentiles, so scores tend to be closer to the mean for this subset.

# %% [markdown]
# ### Scaterplots

# %% [markdown]
# ##### While the previous visualizations were able to tell us some degree of useful information, the most applicable plots to our problem statement will be the following scatterplots. They will better allow us to see the correlation of spending per pupil and resulting scores for both SAT and ACT.

# %%
merged_df.head()
# Out:
#         state  sat_participation  ebrw  math  sat_total  act_participation  \
# 0     Alabama               0.06   595   571       1166               1.00
# 1      Alaska               0.43   562   544       1106               0.33
# 2     Arizona               0.29   577   572       1149               0.66
# 3    Arkansas               0.05   592   576       1169               1.00
# 4  California               0.60   540   536       1076               0.27
#
#    act_score  total_spending_per_pupil
# 0       19.1                    9696.0
# 1       20.8                   17726.0
# 2       19.2                    8239.0
# 3       19.4                   10139.0
# 4       22.7                   12498.0

# %%
#First scatter is our comparison of Nationwide SAT scores against spending per pupil:
plt.figure(figsize=(10,10))
sns.scatterplot(x='total_spending_per_pupil', y='sat_total', data=merged_df)
plt.xlabel('Spending Per Pupil')
plt.ylabel('SAT Scores')
plt.title('Relationship Between SAT Score and Spending per Pupil (Nationwide)');

# %%
#Let's contextualize the above by applying the same scatter method to the states with prevalant SAT participations rates:
plt.figure(figsize=(10,10))
sns.scatterplot(x='total_spending_per_pupil', y='sat_total', data=sat_preferred)
plt.xlabel('Spending Per Pupil')
plt.ylabel('SAT Scores')
plt.title('Relationship Between SAT Score and Spending per Pupil (SAT Pref)');

# %%
#Now let's try the same thing with ACT Scores:
plt.figure(figsize=(10,10))
sns.scatterplot(x='total_spending_per_pupil', y='act_score', data=merged_df)
plt.xlabel('Spending Per Pupil')
plt.ylabel('ACT Scores')
plt.title('Relationship Between ACT Score and Spending per Pupil (Nationwide)');

# %%
#And one last time with preferred states:
#Now let's try the same thing with ACT Scores:
plt.figure(figsize=(10,10))
sns.scatterplot(x='total_spending_per_pupil', y='act_score', data=act_preferred)
plt.xlabel('Spending Per Pupil')
plt.ylabel('ACT Scores')
plt.title('Relationship Between ACT Score and Spending per Pupil (ACT Pref)');

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Make sure to answer your question of interest or address your problem statement here.

# %% [markdown]
# ##### Based on the analysis, if states want their students to succeed on either the SAT and more demonstrably the ACTs I would suggest allocating more spending on funding per pupil. While this seems like an intuitive suggestion, I think it's important to also note that there is no clear direct cause-effect relationship. Higher spending doesn't always result in higher scores as there are (as we might expect) many factors in play. But I would argue that shown from specifically our scatter plot comparisons, there is enough of a trend towards the belief that the more you allocate towards student spending, the better the testing results. We must also keep these findings contextualized which is why it was important to understand the participation rates of each exam across the state. In order to maximize our analysis we want to make sure we compare funding to the more frequent occuring exam scores. Otherwise if we are a state with lower funding but see high SAT scores (at only a 4% participation rate) and then underperforming ACT scores at a much higher rate, we won't be mislead to assume our funding is sufficiently allocated.

# %% [markdown]
# Don't forget to create your README!
#
# **To-Do:** *If you combine your problem statement, data dictionary, brief summary of your analysis, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.* Don't forget to cite your data sources!
